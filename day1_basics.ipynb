# %% [markdown]
# <a href="https://colab.research.google.com/github/baharehafrand/python-practice/blob/main/day1_basics.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Hello AI World")

for i in range(1,6):
    print(i, i*i)
# Out:
# Hello AI World
# 1 1
# 2 4
# 3 9
# 4 16
# 5 25
